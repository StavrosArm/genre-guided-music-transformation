# %%
import polars as pl
import matplotlib.pyplot as plt


FILE_PATH = "./processed_small_dataset.csv"

# %%
df = pl.read_csv(FILE_PATH)
df
# Out:
# shape: (106_574, 53)
# ┌──────────┬──────────┬────────────┬────────────┬───┬────────┬───────────┬────────────┬────────────┐
# │ track_id ┆ comments ┆ date_creat ┆ date_relea ┆ … ┆ number ┆ publisher ┆ tags_2     ┆ title_1    │
# │ ---      ┆ ---      ┆ ed         ┆ sed        ┆   ┆ ---    ┆ ---       ┆ ---        ┆ ---        │
# │ i64      ┆ i64      ┆ ---        ┆ ---        ┆   ┆ i64    ┆ str       ┆ str        ┆ str        │
# │          ┆          ┆ str        ┆ str        ┆   ┆        ┆           ┆            ┆            │
# ╞══════════╪══════════╪════════════╪════════════╪═══╪════════╪═══════════╪════════════╪════════════╡
# │ 2        ┆ 0        ┆ 2008-11-26 ┆ 2009-01-05 ┆ … ┆ 3      ┆ null      ┆ []         ┆ Food       │
# │          ┆          ┆ 01:44:45   ┆ 00:00:00   ┆   ┆        ┆           ┆            ┆            │
# │ 3        ┆ 0        ┆ 2008-11-26 ┆ 2009-01-05 ┆ … ┆ 4      ┆ null      ┆ []         ┆ Electric   │
# │          ┆          ┆ 01:44:45   ┆ 00:00:00   ┆   ┆        ┆           ┆            ┆ Ave        │
# │ 5        ┆ 0        ┆ 2008-11-26 ┆ 2009-01-05 ┆ … ┆ 6      ┆ null      ┆ []         ┆ This World │
# │          ┆          ┆ 01:44:45   ┆ 00:00:00   ┆   ┆        ┆           ┆            ┆            │
# │ 10       ┆ 0        ┆ 2008-11-26 ┆ 2008-02-06 ┆ … ┆ 1      ┆ null      ┆ []         ┆ Freeway    │
# │          ┆          ┆ 01:45:08   ┆ 00:00:00   ┆   ┆        ┆           ┆            ┆            │
# │ 20       ┆ 0        ┆ 2008-11-26 ┆ 2009-01-06 ┆ … ┆ 3      ┆ null      ┆ []         ┆ Spiritual  │
# │          ┆          ┆ 01:45:05   ┆ 00:00:00   ┆   ┆        ┆           ┆            ┆ Level      │
# │ …        ┆ …        ┆ …          ┆ …          ┆ … ┆ …      ┆ …         ┆ …          ┆ …          │
# │ 155316   ┆ 0        ┆ 2017-03-30 ┆ 2017-02-17 ┆ … ┆ 3      ┆ null      ┆ []         ┆ The Auger  │
# │          ┆          ┆ 15:20:35   ┆ 00:00:00   ┆   ┆        ┆           ┆            ┆            │
# │ 155317   ┆ 0        ┆ 2017-03-30 ┆ 2017-02-17 ┆ … ┆ 4      ┆ null      ┆ []         ┆ Let's Skin │
# │          ┆          ┆ 15:20:35   ┆ 00:00:00   ┆   ┆        ┆           ┆            ┆ Ruby       │
# │ 155318   ┆ 0        ┆ 2017-03-30 ┆ 2017-02-17 ┆ … ┆ 6      ┆ null      ┆ []         ┆ My House   │
# │          ┆          ┆ 15:20:35   ┆ 00:00:00   ┆   ┆        ┆           ┆            ┆ Smells     │
# │          ┆          ┆            ┆            ┆   ┆        ┆           ┆            ┆ Like Kim   │
# │          ┆          ┆            ┆            ┆   ┆        ┆           ┆            ┆ Deal/…     │
# │ 155319   ┆ 0        ┆ 2017-03-30 ┆ 2017-02-17 ┆ … ┆ 5      ┆ null      ┆ []         ┆ The Man    │
# │          ┆          ┆ 15:20:35   ┆ 00:00:00   ┆   ┆        ┆           ┆            ┆ With Two   │
# │          ┆          ┆            ┆            ┆   ┆        ┆           ┆            ┆ Mouths     │
# │ 155320   ┆ 0        ┆ 2017-03-26 ┆ 2017-03-26 ┆ … ┆ 7      ┆ null      ┆ ['ballad', ┆ Another    │
# │          ┆          ┆ 16:22:18   ┆ 00:00:00   ┆   ┆        ┆           ┆ 'epic',    ┆ Trick Up   │
# │          ┆          ┆            ┆            ┆   ┆        ┆           ┆ 'rockabill ┆ My Sleeve  │
# │          ┆          ┆            ┆            ┆   ┆        ┆           ┆ y…         ┆ (In…       │
# └──────────┴──────────┴────────────┴────────────┴───┴────────┴───────────┴────────────┴────────────┘

# %%
df["genre_top"]
# Out:
# shape: (106_574,)
# Series: 'genre_top' [str]
# [
# 	"Hip-Hop"
# 	"Hip-Hop"
# 	"Hip-Hop"
# 	"Pop"
# 	null
# 	…
# 	"Rock"
# 	"Rock"
# 	"Rock"
# 	"Rock"
# 	null
# ]

# %%
genre_counts = df.group_by("genre_top").len().drop_nulls()
genre_counts
# Out:
# shape: (16, 2)
# ┌────────────────┬───────┐
# │ genre_top      ┆ len   │
# │ ---            ┆ ---   │
# │ str            ┆ u32   │
# ╞════════════════╪═══════╡
# │ Jazz           ┆ 571   │
# │ Folk           ┆ 2803  │
# │ Blues          ┆ 110   │
# │ Easy Listening ┆ 24    │
# │ Spoken         ┆ 423   │
# │ …              ┆ …     │
# │ International  ┆ 1389  │
# │ Pop            ┆ 2332  │
# │ Rock           ┆ 14182 │
# │ Instrumental   ┆ 2079  │
# │ Electronic     ┆ 9372  │
# └────────────────┴───────┘

# %%
# Extract columns as lists directly from Polars
genres = genre_counts["genre_top"].to_list()
counts = genre_counts["len"].to_list()

# Plot
plt.figure(figsize=(10,6))
plt.bar(genres, counts)
plt.xticks(rotation=90)
plt.xlabel("Genre")
plt.ylabel("Count")
plt.title("Top Genre per Sample")
plt.tight_layout()
plt.show()
